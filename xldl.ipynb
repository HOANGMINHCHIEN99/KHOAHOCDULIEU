# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('apartment_price_TP_HCM.csv')
data.head()
# Out:
#              Tên chung cư          Đường/Phố Xã/Phường/Thị Trấn Quận/Huyện
# 0          Feliz En Vista      Đồng Văn Cống       Thạnh Mỹ Lợi     Quận 2  \
# 1              La Astoria   Nguyễn Duy Trinh     Bình Trưng Tây     Quận 2
# 2     Akari City Nam Long        Võ Văn Kiệt             An Lạc   Bình Tân
# 3            Celadon City                 N1             Sơn Kỳ    Tân Phú
# 4   Empire City Thủ Thiêm        Mai Chí Thọ          Thủ Thiêm     Quận 2
#
#    Diện tích  Mức giá  Số phòng ngủ  Số toilet
# 0      100.0      5.8           3.0        1.0
# 1      135.0      3.0           3.0        3.0
# 2      143.0      2.4           3.0        NaN
# 3       38.0      9.5           2.0        2.0
# 4       51.0      3.7           1.0        2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3695 entries, 0 to 3694
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Tên chung cư        3695 non-null   object
#  1   Đường/Phố           3181 non-null   object
#  2   Xã/Phường/Thị Trấn  3541 non-null   object
#  3   Quận/Huyện          3609 non-null   object
#  4   Diện tích           3695 non-null   float64
#  5   Mức giá             3693 non-null   float64
#  6   Số phòng ngủ        3695 non-null   float64
#  7   Số toilet           3459 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 231.1+ KB

# %%
data.nunique()
# Out:
# Tên chung cư          605
# Đường/Phố             231
# Xã/Phường/Thị Trấn    144
# Quận/Huyện             34
# Diện tích             342
# Mức giá               526
# Số phòng ngủ            5
# Số toilet               6
# dtype: int64

# %%
for i in list(data.columns):
    if data[i].isnull().sum() >= 0:
        print(i, ': ', data[i].isnull().sum())
# Out:
# Tên chung cư :  0
# Đường/Phố :  514
# Xã/Phường/Thị Trấn :  154
# Quận/Huyện :  86
# Diện tích :  0
# Mức giá :  2
# Số phòng ngủ :  0
# Số toilet :  236

# %%
data['Mức giá'].unique()
# Out:
# array([ 5.8  ,  3.   ,  2.4  ,  9.5  ,  3.7  ,  7.3  ,  7.   , 20.   ,
#         4.5  ,  2.35 ,  5.5  ,  1.5  ,  4.3  ,  6.9  ,  2.8  ,  4.65 ,
#         1.85 ,  2.3  ,  5.6  ,  1.92 ,  4.417,  5.408, 12.5  ,  5.85 ,
#         7.8  ,  3.6  ,  6.3  ,  1.9  , 36.78 ,  2.25 , 13.2  ,  4.9  ,
#         1.59 ,  1.55 ,  4.1  ,  3.15 ,  7.5  ,  5.7  , 13.8  ,  2.6  ,
#         6.5  ,  6.4  ,  5.45 ,  1.33 , 11.   ,  2.2  ,  1.7  ,  3.12 ,
#         3.1  ,  1.835, 10.   , 13.5  ,  1.07 ,  3.2  ,  2.99 ,  1.03 ,
#         3.13 ,  1.95 ,  8.1  ,  2.37 ,  1.3  ,  1.43 ,  2.7  ,  3.39 ,
#         4.2  ,  5.4  , 14.   ,  8.5  ,  2.   ,  5.15 ,  2.55 ,  1.86 ,
#         2.88 ,  1.36 ,  5.95 ,  3.22 ,  5.2  , 90.   ,  5.1  ,  4.   ,
#         1.05 ,  1.87 ,  2.75 ,  1.54 , 32.   ,  4.95 ,  2.95 ,  3.5  ,
#        16.   , 25.5  ,  5.9  ,  2.5  ,  4.55 ,  2.65 ,  1.75 , 22.5  ,
#        26.   , 17.52 ,  5.151,  4.31 ,  7.4  ,  4.308,  6.69 ,  3.47 ,
#         9.35 , 12.6  ,  5.558,  5.93 ,  5.73 ,  4.18 , 22.1  ,  5.28 ,
#        10.568, 62.   ,  1.889,  4.403,  4.97 ,  5.64 ,  3.375,  2.52 ,
#         2.56 ,  1.97 ,  2.999,  2.28 ,  2.399,  4.48 ,  2.27 ,  2.954,
#         3.315,  1.06 ,  1.27 ,  1.78 ,  1.58 , 46.   ,  5.99 ,  2.269,
#        80.   ,  2.51 , 19.8  ,  2.43 ,  1.51 ,  1.88 ,  2.082, 12.8  ,
#         1.15 , 22.6  ,  8.4  ,  4.711,  7.999, 11.1  ,  6.04 ,  3.43 ,
#         1.799, 75.   ,  1.98 , 18.8  ,  6.58 , 30.3  ,  2.362,  3.97 ,
#         3.745,  9.12 ,  1.81 ,  1.79 , 11.195,  1.69 ,  1.76 ,  2.48 ,
#         1.425,  1.37 ,  1.82 ,  1.83 , 52.7  ,  9.9  ,  1.53 ,  3.92 ,
#         2.08 ,  1.21 , 11.7  ,  3.32 ,  1.834,  5.899,  1.625,  1.34 ,
#         1.41 ,  9.4  , 10.7  ,  1.46 , 12.3  ,  3.179, 98.   ,  7.75 ,
#         6.35 ,  4.854,  2.285,  2.59 ,  8.2  ,  5.49 ,  3.29 ,  4.388,
#        13.9  ,  2.475,  7.45 ,  2.447,  4.175, 85.   , 21.6  ,  2.22 ,
#         7.42 ,  6.199,  4.982,  6.65 , 26.7  ,  5.717, 10.1  ,  1.77 ,
#         4.049,  5.78 ,  6.49 ,  7.49 ,  5.79 ,  5.68 ,  1.888,  8.45 ,
#        31.   ,  4.988, 19.6  ,  1.84 ,  7.1  ,  2.49 ,  8.943,  4.08 ,
#         5.444,  4.98 ,  5.46 ,  4.58 , 10.9  ,  9.26 , 15.2  ,  3.67 ,
#        36.9  , 23.5  ,  4.446,  3.19 ,  6.29 ,  2.102,  3.089,  2.53 ,
#         2.73 ,  8.89 ,  3.531,  6.55 ,  6.684,  2.453, 17.3  ,  9.11 ,
#         4.12 ,  8.85 ,  5.999,  2.69 ,  3.16 ,  4.28 ,  4.44 ,  3.254,
#         2.89 ,  1.667, 34.   ,  5.58 ,  2.62 ,  3.289, 58.5  ,  4.616,
#         2.07 ,  3.885,  1.435, 44.   , 63.   ,  3.04 ,  4.56 , 22.653,
#         3.336, 15.1  ,  4.696,  4.03 ,  5.199,  7.727,  4.608])

# %%
plt.plot(data['Mức giá'])

# %%
data['Mức giá'] = data['Mức giá'].replace(np.nan,data['Mức giá'].mean())
data['Số phòng ngủ'] = data['Số phòng ngủ'].replace(np.nan,np.trunc(data['Số phòng ngủ'].mean()))
data['Số toilet'] = data['Số toilet'].replace(np.nan,np.trunc(data['Số toilet'].mean()))
data
# Out:
#                 Tên chung cư           Đường/Phố Xã/Phường/Thị Trấn
# 0             Feliz En Vista       Đồng Văn Cống       Thạnh Mỹ Lợi  \
# 1                 La Astoria    Nguyễn Duy Trinh     Bình Trưng Tây
# 2        Akari City Nam Long         Võ Văn Kiệt             An Lạc
# 3               Celadon City                  N1             Sơn Kỳ
# 4      Empire City Thủ Thiêm         Mai Chí Thọ          Thủ Thiêm
# ...                      ...                 ...                ...
# 3690   Zeit River Thủ Thiêm                  NaN           An Khánh
# 3691               De La Sol     Tôn Thất Thuyết                  1
# 3692   Zeit River Thủ Thiêm                  NaN          Thủ Thiêm
# 3693                The Marq   Nguyễn Đình Chiểu             Đa Kao
# 3694       Lumiere Boulevard         Nguyễn Xiển          Long Bình
#
#      Quận/Huyện  Diện tích  Mức giá  Số phòng ngủ  Số toilet
# 0        Quận 2     100.00    5.800           3.0        1.0
# 1        Quận 2     135.00    3.000           3.0        3.0
# 2      Bình Tân     143.00    2.400           3.0        1.0
# 3       Tân Phú      38.00    9.500           2.0        2.0
# 4        Quận 2      51.00    3.700           1.0        2.0
# ...         ...        ...      ...           ...        ...
# 3690     Quận 2      74.90    5.199           2.0        2.0
# 3691     Quận 4      94.00    7.727           2.0        2.0
# 3692     Quận 2      73.00   13.900           2.0        2.0
# 3693     Quận 1      72.32    4.608           2.0        2.0
# 3694     Quận 9      63.00    2.100           2.0        2.0
#
# [3695 rows x 8 columns]

# %%
cat_features = np.array([i for i in data.columns.tolist() if data[i].dtype == 'object'])
f, ax = plt.subplots(2, 2, figsize=(10, 10))
k = 0

for i in range(2):
    for j in range(2):
        if k < 4:
            sns.countplot(x=cat_features[k], data=data, ax=ax[i, j], palette='Set3')
            k += 1

# %%
def outliers(data_temp, k=3):
    q1, q3 = np.percentile(data_temp, [25, 75])
    
    iqr = q3 - q1
    lower_bound = q1 - (k * iqr)
    upper_bound = q3 + (k * iqr)
    
    outliers = [index for index,x in enumerate(data_temp) if x < lower_bound or x > upper_bound]
    
    return outliers

# %%
cont_features = np.array([i for i in data.columns.tolist() if data[i].dtype != 'object'])
raws = []
for i in cont_features:
    raws += outliers(data[i])

len(set(raws))
# Out:
# 172

# %%
list(set(raws))
# Out:
# [2048,
#  3584,
#  3586,
#  3075,
#  3587,
#  1029,
#  3590,
#  2567,
#  3592,
#  7,
#  1037,
#  1041,
#  3094,
#  2586,
#  1564,
#  1568,
#  33,
#  1573,
#  3621,
#  3113,
#  3625,
#  2605,
#  3126,
#  3127,
#  3128,
#  1081,
#  3647,
#  3650,
#  2633,
#  1616,
#  2128,
#  3664,
#  2135,
#  88,
#  91,
#  3676,
#  1117,
#  2139,
#  3163,
#  2656,
#  2145,
#  3683,
#  2661,
#  3173,
#  1127,
#  617,
#  1642,
#  107,
#  620,
#  1645,
#  108,
#  3183,
#  1649,
#  627,
#  1654,
#  119,
#  2169,
#  123,
#  124,
#  129,
#  1672,
#  137,
#  1167,
#  144,
#  145,
#  1169,
#  659,
#  660,
#  2202,
#  1695,
#  1184,
#  1185,
#  3243,
#  1197,
#  3250,
#  2227,
#  701,
#  1215,
#  704,
#  2242,
#  2243,
#  1732,
#  3271,
#  1737,
#  3273,
#  2255,
#  1231,
#  2261,
#  2263,
#  218,
#  2268,
#  221,
#  2270,
#  2783,
#  736,
#  2780,
#  2781,
#  739,
#  2789,
#  3304,
#  236,
#  1261,
#  1263,
#  2802,
#  1781,
#  3319,
#  760,
#  766,
#  3329,
#  770,
#  774,
#  2824,
#  2825,
#  2831,
#  275,
#  1827,
#  2343,
#  1331,
#  1845,
#  2359,
#  2879,
#  326,
#  853,
#  854,
#  1887,
#  1383,
#  3434,
#  2416,
#  881,
#  883,
#  885,
#  2939,
#  2941,
#  2942,
#  2943,
#  2945,
#  900,
#  901,
#  1419,
#  2955,
#  3468,
#  2446,
#  2963,
#  404,
#  405,
#  1432,
#  3483,
#  1439,
#  1440,
#  3491,
#  3492,
#  937,
#  1452,
#  2476,
#  430,
#  3508,
#  3521,
#  1479,
#  2002,
#  980,
#  473,
#  1504,
#  3042,
#  3047,
#  1514,
#  2539,
#  2544,
#  1527,
#  1528,
#  1530,
#  3581,
#  3583]

# %%
data.drop(list(set(raws)), axis=0, inplace=True)

# %%
f,ax = plt.subplots(4,1, figsize=(28,42))
k=0
for j in range(4):
    if k<5:
        ax[j].scatter(x=cont_features[k], y='Mức giá', data=data, s=1, c='red')
        ax[j].set_xlabel(cont_features[k])
        ax[j].set_ylabel('Mức giá')
        k=k+1
plt.show()

# %%
X = data.drop(['Mức giá'],axis=1)
y = data['Mức giá']
tenchungcu = data ['Tên chung cư'].unique()
duongpho = data['Đường/Phố'].unique()
quanhuyen = data['Quận/Huyện'].unique()
xaphuong = data['Xã/Phường/Thị Trấn'].unique()

# %%
cat_features = np.array([i for i in data.columns.tolist() if data[i].dtype == 'object'])
cont_features = np.array([i for i in data.columns.tolist() if data[i].dtype != 'object'])

# %%
from sklearn.preprocessing import LabelEncoder
for i in cat_features:
    enc = LabelEncoder()
    X[i] =enc.fit_transform(X[i])

# %%
plt.figure(figsize=(20,20))
sns.heatmap(X.corr(), cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.plot(data['Mức giá'])

# %%
from sklearn.linear_model import LinearRegression
import pickle

model = LinearRegression()
model.fit(X,y)

filename = 'model.sav'
pickle.dump(model, open(filename, 'wb'))

data['dudoan']=model.predict(X)
data[['Mức giá','dudoan']].plot()
# Out:
# <Axes: >

# %%
a=np.sqrt(pow(data['dudoan']-data['Mức giá'],2).mean())
print(a)
# Out:
# 1.8796929088183054

# %%
X['Quận/Huyện'].unique()
# Out:
# array([15,  2, 33, 22, 20,  9,  1, 14, 12, 19, 21,  0, 16, 17, 31, 23,  4,
#         3, 11,  6, 10, 34, 32, 13, 18, 30, 25, 27, 28,  7, 29, 26,  5, 24,
#         8])

# %%
quanhuyen
# Out:
# array([' Quận 2', ' Bình Tân', ' Tân Phú', ' Quận 9', ' Quận 7',
#        ' Nhà Bè', ' Bình Thạnh', ' Quận 12', ' Quận 10', ' Quận 6',
#        ' Quận 8', ' Bình Chánh', ' Quận 3', ' Quận 4', ' Thủ Đức',
#        ' Quận Bình Thạnh', ' Huyện Bình Chánh', ' Gò Vấp', ' Quận 1',
#        ' Hóc Môn', ' Phú Nhuận', nan, ' Tân Bình', ' Quận 11', ' Quận 5',
#        ' Thành phố Thủ Đức', ' Quận Gò Vấp', ' Quận Tân Bình',
#        ' Quận Tân Phú', ' Hồ Ch', ' T', ' Quận Phú Nhuận',
#        ' Huyện Nhà Bè', ' Quận Bình Tân', ' Hồ Chí Minh'], dtype=object)

# %%
y.max(0)
# Out:
# 15.1
